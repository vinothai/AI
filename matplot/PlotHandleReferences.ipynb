# %%
import matplotlib.pyplot as plt

fig1, ((axes1, axes2), (axes3, axes4)) = plt.subplots(2, 2)

axes1.plot([1, 2, 3, 4, 5], [2, 4, 6, 8, 16], 'b*--')
axes4.plot([1, 3, 5, 7, 9], [0, 6, 10, 14, 18], 'yx-')

plt.tight_layout()
plt.show()
